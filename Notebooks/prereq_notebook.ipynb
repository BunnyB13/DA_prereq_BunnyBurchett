# %%
# Importing matplotlib for visualization
import matplotlib.pyplot as plt

# Define categories and scores
categories = ["Python", "Excel", "SQL", "Power BI"]
scores = [45, 95, 10, 0]

# Create a bar chart
plt.bar(categories, scores)

# Add a title and labels
plt.title("My Data Skills Progress")
plt.xlabel("Skill")
plt.ylabel("Confidence Level (%)")

# Display the chart
plt.show()

# %% [markdown]
# ## About Me
#
# Hi there! I'm **Bunny Burchett**, a master's student in Organizational Psychology and MBA candidate at the University of Hartford.
#
# I'm passionate about **corporate learning and development**, with a focus on designing inclusive and gamified training experiences for neurodiverse employees.
#
# Right now, I'm sharpening my **data analytics skills** so I can turn learning outcomes into actionable insights for organizations.
#
# Outside of work and school, I enjoy video games, crocheting, and music from around the world — they keep my creativity flowing. 🎮🧶🎵
#
# I'm excited to continue growing my technical skills and connecting data with human-centered design!
